# %%
from sklearn.datasets import load_iris
iris = load_iris()
X = iris.data
y = iris.target

# %%
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.2],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.6, 1.4, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)
print(X_pca)
# Out:
# [[-2.68412563  0.31939725]
#  [-2.71414169 -0.17700123]
#  [-2.88899057 -0.14494943]
#  [-2.74534286 -0.31829898]
#  [-2.72871654  0.32675451]
#  [-2.28085963  0.74133045]
#  [-2.82053775 -0.08946138]
#  [-2.62614497  0.16338496]
#  [-2.88638273 -0.57831175]
#  [-2.6727558  -0.11377425]
#  [-2.50694709  0.6450689 ]
#  [-2.61275523  0.01472994]
#  [-2.78610927 -0.235112  ]
#  [-3.22380374 -0.51139459]
#  [-2.64475039  1.17876464]
#  [-2.38603903  1.33806233]
#  [-2.62352788  0.81067951]
#  [-2.64829671  0.31184914]
#  [-2.19982032  0.87283904]
#  [-2.5879864   0.51356031]
#  [-2.31025622  0.39134594]
#  [-2.54370523  0.43299606]
#  [-3.21593942  0.13346807]
#  [-2.30273318  0.09870885]
#  [-2.35575405 -0.03728186]
#  [-2.50666891 -0.14601688]
#  [-2.46882007  0.13095149]
#  [-2.56231991  0.36771886]
#  [-2.63953472  0.31203998]
#  [-2.63198939 -0.19696122]
#  [-2.58739848 -0.20431849]
#  [-2.4099325   0.41092426]
#  [-2.64886233  0.81336382]
#  [-2.59873675  1.09314576]
#  [-2.63692688 -0.12132235]
#  [-2.86624165  0.06936447]
#  [-2.62523805  0.59937002]
#  [-2.80068412  0.26864374]
#  [-2.98050204 -0.48795834]
#  [-2.59000631  0.22904384]
#  [-2.77010243  0.26352753]
#  [-2.84936871 -0.94096057]
#  [-2.99740655 -0.34192606]
#  [-2.40561449  0.18887143]
#  [-2.20948924  0.43666314]
#  [-2.71445143 -0.2502082 ]
#  [-2.53814826  0.50377114]
#  [-2.83946217 -0.22794557]
#  [-2.54308575  0.57941002]
#  [-2.70335978  0.10770608]
#  [ 1.28482569  0.68516047]
#  [ 0.93248853  0.31833364]
#  [ 1.46430232  0.50426282]
#  [ 0.18331772 -0.82795901]
#  [ 1.08810326  0.07459068]
#  [ 0.64166908 -0.41824687]
#  [ 1.09506066  0.28346827]
#  [-0.74912267 -1.00489096]
#  [ 1.04413183  0.2283619 ]
#  [-0.0087454  -0.72308191]
#  [-0.50784088 -1.26597119]
#  [ 0.51169856 -0.10398124]
#  [ 0.26497651 -0.55003646]
#  [ 0.98493451 -0.12481785]
#  [-0.17392537 -0.25485421]
#  [ 0.92786078  0.46717949]
#  [ 0.66028376 -0.35296967]
#  [ 0.23610499 -0.33361077]
#  [ 0.94473373 -0.54314555]
#  [ 0.04522698 -0.58383438]
#  [ 1.11628318 -0.08461685]
#  [ 0.35788842 -0.06892503]
#  [ 1.29818388 -0.32778731]
#  [ 0.92172892 -0.18273779]
#  [ 0.71485333  0.14905594]
#  [ 0.90017437  0.32850447]
#  [ 1.33202444  0.24444088]
#  [ 1.55780216  0.26749545]
#  [ 0.81329065 -0.1633503 ]
#  [-0.30558378 -0.36826219]
#  [-0.06812649 -0.70517213]
#  [-0.18962247 -0.68028676]
#  [ 0.13642871 -0.31403244]
#  [ 1.38002644 -0.42095429]
#  [ 0.58800644 -0.48428742]
#  [ 0.80685831  0.19418231]
#  [ 1.22069088  0.40761959]
#  [ 0.81509524 -0.37203706]
#  [ 0.24595768 -0.2685244 ]
#  [ 0.16641322 -0.68192672]
#  [ 0.46480029 -0.67071154]
#  [ 0.8908152  -0.03446444]
#  [ 0.23054802 -0.40438585]
#  [-0.70453176 -1.01224823]
#  [ 0.35698149 -0.50491009]
#  [ 0.33193448 -0.21265468]
#  [ 0.37621565 -0.29321893]
#  [ 0.64257601  0.01773819]
#  [-0.90646986 -0.75609337]
#  [ 0.29900084 -0.34889781]
#  [ 2.53119273 -0.00984911]
#  [ 1.41523588 -0.57491635]
#  [ 2.61667602  0.34390315]
#  [ 1.97153105 -0.1797279 ]
#  [ 2.35000592 -0.04026095]
#  [ 3.39703874  0.55083667]
#  [ 0.52123224 -1.19275873]
#  [ 2.93258707  0.3555    ]
#  [ 2.32122882 -0.2438315 ]
#  [ 2.91675097  0.78279195]
#  [ 1.66177415  0.24222841]
#  [ 1.80340195 -0.21563762]
#  [ 2.1655918   0.21627559]
#  [ 1.34616358 -0.77681835]
#  [ 1.58592822 -0.53964071]
#  [ 1.90445637  0.11925069]
#  [ 1.94968906  0.04194326]
#  [ 3.48705536  1.17573933]
#  [ 3.79564542  0.25732297]
#  [ 1.30079171 -0.76114964]
#  [ 2.42781791  0.37819601]
#  [ 1.19900111 -0.60609153]
#  [ 3.49992004  0.4606741 ]
#  [ 1.38876613 -0.20439933]
#  [ 2.2754305   0.33499061]
#  [ 2.61409047  0.56090136]
#  [ 1.25850816 -0.17970479]
#  [ 1.29113206 -0.11666865]
#  [ 2.12360872 -0.20972948]
#  [ 2.38800302  0.4646398 ]
#  [ 2.84167278  0.37526917]
#  [ 3.23067366  1.37416509]
#  [ 2.15943764 -0.21727758]
#  [ 1.44416124 -0.14341341]
#  [ 1.78129481 -0.49990168]
#  [ 3.07649993  0.68808568]
#  [ 2.14424331  0.1400642 ]
#  [ 1.90509815  0.04930053]
#  [ 1.16932634 -0.16499026]
#  [ 2.10761114  0.37228787]
#  [ 2.31415471  0.18365128]
#  [ 1.9222678   0.40920347]
#  [ 1.41523588 -0.57491635]
#  [ 2.56301338  0.2778626 ]
#  [ 2.41874618  0.3047982 ]
#  [ 1.94410979  0.1875323 ]
#  [ 1.52716661 -0.37531698]
#  [ 1.76434572  0.07885885]
#  [ 1.90094161  0.11662796]
#  [ 1.39018886 -0.28266094]]

# %%
import matplotlib.pyplot as plt
colors = ['navy', 'turquoise', 'darkorange']
for X_transformed, title in [(X_pca, "PCA")]:
    plt.figure(figsize=(8, 8))
    for color, i, target_name in zip(colors, [0, 1, 2], iris.target_names):
        plt.scatter(X_transformed[y == i, 0], X_transformed[y == i, 1],
            color=color, lw=2, label=target_name)
        plt.title(title + " of iris dataset")
    plt.legend(loc="best", shadow=False, scatterpoints=1)
plt.show()

# %%
from sklearn.decomposition import FastICA
ica = FastICA(n_components=2)
X_ica = ica.fit_transform(X)
print(X_ica)
# Out:
# [[ 0.11208864  0.04114748]
#  [ 0.10428187 -0.04104345]
#  [ 0.11178732 -0.03650398]
#  [ 0.10295701 -0.06453711]
#  [ 0.11398792  0.04217014]
#  [ 0.103764    0.11264881]
#  [ 0.11008188 -0.02703396]
#  [ 0.10696522  0.01560849]
#  [ 0.10383084 -0.10813264]
#  [ 0.10378861 -0.0304116 ]
#  [ 0.11097343  0.0957541 ]
#  [ 0.10374108 -0.00890784]
#  [ 0.10607897 -0.05096229]
#  [ 0.11840652 -0.09853529]
#  [ 0.12610232  0.18338214]
#  [ 0.11874317  0.21083912]
#  [ 0.11859156  0.1226254 ]
#  [ 0.11053291  0.04005523]
#  [ 0.1029377   0.13474057]
#  [ 0.11179973  0.07366233]
#  [ 0.09858594  0.05466455]
#  [ 0.10858609  0.06053634]
#  [ 0.12978098  0.00810237]
#  [ 0.09298496  0.0063208 ]
#  [ 0.09262041 -0.01639028]
#  [ 0.09662671 -0.03502065]
#  [ 0.10014686  0.01092985]
#  [ 0.10814037  0.04966442]
#  [ 0.11018936  0.04012482]
#  [ 0.10066665 -0.04398642]
#  [ 0.09876737 -0.04500908]
#  [ 0.10288825  0.05746836]
#  [ 0.11964353  0.12295916]
#  [ 0.12272847  0.16942808]
#  [ 0.10223288 -0.03150385]
#  [ 0.11477008 -0.00097656]
#  [ 0.11483003  0.08768598]
#  [ 0.11578503  0.03225129]
#  [ 0.10919563 -0.09360475]
#  [ 0.10672384  0.02661958]
#  [ 0.11448117  0.03153829]
#  [ 0.09579319 -0.16792215]
#  [ 0.11251144 -0.06953725]
#  [ 0.0986933   0.02077911]
#  [ 0.09541644  0.0625935 ]
#  [ 0.10296751 -0.05314678]
#  [ 0.10964857  0.07226043]
#  [ 0.1083218  -0.05000922]
#  [ 0.11121481  0.08474301]
#  [ 0.10901421  0.00606889]
#  [-0.03846737  0.11884311]
#  [-0.03116107  0.05667262]
#  [-0.04885341  0.08971773]
#  [-0.02226392 -0.1360757 ]
#  [-0.04174096  0.01705456]
#  [-0.0329916  -0.06635551]
#  [-0.03823131  0.05161474]
#  [ 0.01145766 -0.16937271]
#  [-0.03721296  0.04228389]
#  [-0.01275702 -0.11957207]
#  [-0.00282911 -0.21148492]
#  [-0.02214934 -0.01496788]
#  [-0.0204615  -0.08977726]
#  [-0.04126871 -0.01635795]
#  [ 0.00226969 -0.04288552]
#  [-0.02828048  0.08125853]
#  [-0.03254588 -0.0554836 ]
#  [-0.01539612 -0.05412484]
#  [-0.04725737 -0.08568705]
#  [-0.01237113 -0.09631847]
#  [-0.04574207 -0.00914201]
#  [-0.01542265 -0.00984042]
#  [-0.05735259 -0.04855131]
#  [-0.03981515 -0.0262072 ]
#  [-0.02560954  0.02774416]
#  [-0.02969701  0.05821369]
#  [-0.04832313  0.04619178]
#  [-0.05684692  0.05098316]
#  [-0.03516929 -0.02347299]
#  [ 0.00542869 -0.0622048 ]
#  [-0.01008077 -0.11686916]
#  [-0.00481815 -0.11328277]
#  [-0.0110938  -0.05132104]
#  [-0.06228217 -0.06359762]
#  [-0.03206313 -0.07750577]
#  [-0.0284355   0.03560351]
#  [-0.04095688  0.07268384]
#  [-0.03902248 -0.05796357]
#  [-0.01460685 -0.04332251]
#  [-0.01894811 -0.1120082 ]
#  [-0.03056204 -0.1088588 ]
#  [-0.03590391 -0.00183005]
#  [-0.0164586  -0.06584894]
#  [ 0.00955839 -0.17039537]
#  [-0.02328746 -0.08191791]
#  [-0.01699939 -0.03371333]
#  [-0.02021302 -0.04683932]
#  [-0.02512679  0.00572198]
#  [ 0.02219776 -0.12892659]
#  [-0.01816404 -0.05637892]
#  [-0.10042247  0.0093606 ]
#  [-0.06646662 -0.08889653]
#  [-0.09739737  0.0682112 ]
#  [-0.0813364  -0.02115208]
#  [-0.09379796  0.00354657]
#  [-0.12455247  0.10580762]
#  [-0.04225724 -0.19491446]
#  [-0.10969839  0.07149978]
#  [-0.0963473  -0.03023101]
#  [-0.10132803  0.14206751]
#  [-0.06142245  0.04725759]
#  [-0.07532865 -0.02781829]
#  [-0.08184568  0.04515453]
#  [-0.06738989 -0.12257322]
#  [-0.07258737 -0.08232401]
#  [-0.07326206  0.02798147]
#  [-0.07645436  0.015398  ]
#  [-0.11679324  0.20950231]
#  [-0.1456576   0.05901677]
#  [-0.06530907 -0.12017997]
#  [-0.08929649  0.07306033]
#  [-0.05846791 -0.09498891]
#  [-0.13026082  0.09134931]
#  [-0.05870398 -0.02776055]
#  [-0.08404437  0.06525639]
#  [-0.09336263  0.10407238]
#  [-0.05309781 -0.02424374]
#  [-0.05324752 -0.01368148]
#  [-0.08790288 -0.02545148]
#  [-0.08615319  0.08717767]
#  [-0.10573962  0.07437317]
#  [-0.10304385  0.24119142]
#  [-0.08945861 -0.02654372]
#  [-0.05979266 -0.01743835]
#  [-0.07960443 -0.07490652]
#  [-0.10937086  0.12710495]
#  [-0.08238128  0.03246319]
#  [-0.07455508  0.01642065]
#  [-0.04929925 -0.02219842]
#  [-0.07672226  0.07069351]
#  [-0.08832049  0.0404063 ]
#  [-0.06871306  0.07599146]
#  [-0.06646662 -0.08889653]
#  [-0.0964689   0.05706094]
#  [-0.0902673   0.0608874 ]
#  [-0.0735951   0.03944139]
#  [-0.06728241 -0.05541444]
#  [-0.06844515  0.02069595]
#  [-0.07317039  0.02753264]
#  [-0.06017855 -0.04069195]]

# %%
import matplotlib.pyplot as plt
colors = ['navy', 'turquoise', 'darkorange']
for X_transformed, title in [(X_ica, "ICA")]:
    plt.figure(figsize=(8, 8))
    for color, i, target_name in zip(colors, [0, 1, 2], iris.target_names):
        plt.scatter(X_transformed[y == i, 0], X_transformed[y == i, 1],
            color=color, lw=2, label=target_name)
        plt.title(title + " of iris dataset")
    plt.legend(loc="best", shadow=False, scatterpoints=1)
plt.show()

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis(n_components=2)
X_lda = lda.fit(X, y).transform(X)

# %%
import matplotlib.pyplot as plt
colors = ['navy', 'turquoise', 'darkorange']
for X_transformed, title in [(X_lda, "LDA")]:
    plt.figure(figsize=(8, 8))
    for color, i, target_name in zip(colors, [0, 1, 2], iris.target_names):
        plt.scatter(X_transformed[y == i, 0], X_transformed[y == i, 1],
            color=color, lw=2, label=target_name)
        plt.title(title + " of iris dataset")
    plt.legend(loc="best", shadow=False, scatterpoints=1)
plt.show()

# %%
from sklearn import manifold
tsne = manifold.TSNE(n_components=2, init='pca', random_state=0)
X_tsne = tsne.fit_transform(X)

# %%
import matplotlib.pyplot as plt
colors = ['navy', 'turquoise', 'darkorange']
for X_transformed, title in [(X_tsne, "t-SNE")]:
    plt.figure(figsize=(8, 8))
    for color, i, target_name in zip(colors, [0, 1, 2], iris.target_names):
        plt.scatter(X_transformed[y == i, 0], X_transformed[y == i, 1],
            color=color, lw=2, label=target_name)
        plt.title(title + " of iris dataset")
    plt.legend(loc="best", shadow=False, scatterpoints=1)
plt.show()
